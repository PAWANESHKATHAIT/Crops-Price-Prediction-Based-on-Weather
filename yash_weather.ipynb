# %%
import requests
import pandas as pd
from datetime import datetime
import schedule
import time

# %%
# Initialize a DataFrame to store weather data
weather_df = pd.DataFrame(columns=['timestamp', 'city', 'temperature', 'humidity', 'pressure', 'weather', 'wind_speed', 'season'])

# %%
# Your OpenWeatherMap API key
api_key = '429e6570bf176b57734d33f03e17ea4a'
# List of cities you want to fetch weather data for
cities = ['North and Middle Andaman ', 'Chittor', 'Guntur', 'Visakhapatnam',
       'Barpeta', 'Cachar', 'Goalpara', 'Jorhat', 'Kamrup',
       'Karbi Anglong', 'Kokrajhar', 'MORIGAON', 'Sonitpur', 'Araria',
       'Bhojpur', 'Madhubani', 'Rohtas', 'Chandigarh', 'Bilaspur',
       'Dhamtari', 'Durg', 'Kondagaon', 'Raipur', 'Rajnandgaon',
       'North Goa', 'South Goa', 'Ahmedabad', 'Amreli', 'Anand',
       'Banaskanth', 'Bharuch', 'Bhavnagar', 'Chhota Udaipur', 'Dahod',
       'Dang', 'Devbhumi Dwarka', 'Gandhinagar', 'Gir Somnath',
       'Jamnagar', 'Junagarh', 'Kachchh', 'Kheda', 'Mehsana', 'Morbi',
       'Navsari', 'Panchmahals', 'Patan', 'Porbandar', 'Rajkot',
       'Sabarkantha', 'Surat', 'Surendranagar', 'Vadodara(Baroda)',
       'Valsad', 'Ambala', 'Bhiwani', 'Fatehabad', 'Gurgaon', 'Hissar',
       'Jhajar', 'Jind', 'Kaithal', 'Kurukshetra', 'Mahendragarh-Narnaul',
       'Mewat', 'Panchkula', 'Panipat', 'Rewari', 'Rohtak', 'Sonipat',
       'Yamuna Nagar', 'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi',
       'Shimla', 'Una', 'Anantnag', 'Badgam', 'Baramulla', 'Jammu',
       'Kathua', 'Pulwama', 'Rajouri', 'Srinagar', 'Udhampur',
       'Bangalore', 'Chamrajnagar', 'Chikmagalur', 'Chitradurga',
       'Davangere', 'Kolar', 'Koppal', 'Mandya',
       'Mangalore(Dakshin Kannad)', 'Mysore', 'Raichur', 'Shimoga',
       'Udupi', 'Alappuzha', 'Ernakulam', 'Idukki', 'Kannur', 'Kasargod',
       'Kollam', 'Kottayam', 'Kozhikode(Calicut)', 'Malappuram',
       'Palakad', 'Pathanamthitta', 'Thirssur', 'Thiruvananthapuram',
       'Wayanad', 'Alirajpur', 'Anupur', 'Ashoknagar', 'Badwani',
       'Balaghat', 'Bhind', 'Bhopal', 'Chhatarpur', 'Chhindwara', 'Datia',
       'Dewas', 'Dhar', 'Dindori', 'Guna', 'Gwalior', 'Harda',
       'Hoshangabad', 'Indore', 'Khandwa', 'Khargone', 'Mandla',
       'Mandsaur', 'Morena', 'Narsinghpur', 'Neemuch', 'Rajgarh',
       'Ratlam', 'Sagar', 'Satna', 'Sehore', 'Seoni', 'Shajapur',
       'Sheopur', 'Tikamgarh', 'Ujjain', 'Vidisha', 'Ahmednagar', 'Akola',
       'Buldhana', 'Kolhapur', 'Mumbai', 'Nagpur', 'Nashik', 'Pune',
       'Raigad', 'Ratnagiri', 'Sangli', 'Satara', 'Sholapur', 'Thane',
       'Yavatmal', 'East Khasi Hills', 'Kohima', 'Mokokchung', 'Delhi',
       'Balasore', 'Bargarh', 'Boudh', 'Dhenkanal', 'Kalahandi',
       'Kendrapara', 'Keonjhar', 'Nayagarh', 'Nuapada', 'Rayagada',
       'Sundergarh', 'Amritsar', 'Bhatinda', 'Faridkot', 'Fatehgarh',
       'Fazilka', 'Ferozpur', 'Gurdaspur', 'Hoshiarpur', 'Jalandhar',
       'Ludhiana', 'Mansa', 'Moga', 'Mohali', 'Nawanshahr', 'Pathankot',
       'Patiala', 'Ropar (Rupnagar)', 'Sangrur', 'Tarntaran', 'Ajmer',
       'Baran', 'Bikaner', 'Bundi', 'Churu', 'Ganganagar', 'Hanumangarh',
       'Jalore', 'Jodhpur', 'Jodhpur Rural', 'Pratapgarh', 'Sikar',
       'Tonk', 'Udaipur', 'Ariyalur', 'Chengalpattu', 'Coimbatore',
       'Cuddalore', 'Dharmapuri', 'Dindigul', 'Erode', 'Kallakuruchi',
       'Kancheepuram', 'Karur', 'Krishnagiri', 'Madurai', 'Nagapattinam',
       'Nagercoil (Kannyiakumari)', 'Namakkal', 'Perambalur',
       'Pudukkottai', 'Ramanathapuram', 'Ranipet', 'Salem', 'Sivaganga',
       'Tenkasi', 'Thanjavur', 'The Nilgiris', 'Theni',
       'Thiruchirappalli', 'Thirunelveli', 'Thirupathur', 'Thirupur',
       'Thiruvannamalai', 'Thiruvarur', 'Thiruvellore', 'Tuticorin',
       'Vellore', 'Villupuram', 'Virudhunagar', 'Hyderabad', 'Karimnagar',
       'Khammam', 'Mahbubnagar', 'Medak', 'Nalgonda', 'Nizamabad',
       'Ranga Reddy', 'Warangal', 'Gomati', 'North Tripura', 'Sepahijala',
       'Unokoti', 'Agra', 'Aligarh', 'Ambedkarnagar', 'Amethi', 'Amroha',
       'Auraiya', 'Ayodhya', 'Azamgarh', 'Badaun', 'Baghpat', 'Bahraich',
       'Ballia', 'Balrampur', 'Banda', 'Barabanki', 'Basti',
       'Bhadohi(Sant Ravi Nagar)', 'Bijnor', 'Bulandshahar', 'Chandauli',
       'Etah', 'Etawah', 'Farukhabad', 'Fatehpur', 'Firozabad',
       'Gautam Budh Nagar', 'Ghaziabad', 'Ghazipur', 'Gonda', 'Gorakhpur',
       'Hardoi', 'Jalaun (Orai)', 'Jaunpur', 'Jhansi', 'Kannuj', 'Kanpur',
       'Kasganj', 'Kaushambi', 'Khiri (Lakhimpur)', 'Lakhimpur',
       'Lucknow', 'Maharajganj', 'Mahoba', 'Mainpuri', 'Mathura',
       'Mau(Maunathbhanjan)', 'Meerut', 'Mirzapur', 'Muzaffarnagar',
       'Pillibhit', 'Prayagraj', 'Raebarelli', 'Rampur', 'Saharanpur',
       'Sambhal', 'Sant Kabir Nagar', 'Shahjahanpur', 'Shamli',
       'Siddharth Nagar', 'Sitapur', 'Unnao', 'Varanasi', 'Champawat',
       'Dehradoon', 'Haridwar', 'Nanital', 'UdhamSinghNagar',
       'Alipurduar', 'Bankura', 'Birbhum', 'Darjeeling', 'Howrah',
       'Jalpaiguri', 'Kolkata', 'Medinipur(E)', 'Medinipur(W)',
       'Murshidabad', 'Nadia', 'North 24 Parganas', 'Paschim Bardhaman',
       'Purba Bardhaman', 'Puruliya', 'Sounth 24 Parganas',
       'East Godavari', 'Sibsagar', 'Vaishali', 'Surguja', 'Dharwad',
       'Kalburgi', 'Yadgiri', 'Damoh', 'Jabalpur', 'Katni', 'Panna',
       'Raisen', 'Shehdol', 'Umariya', 'Chandrapur', 'Hingoli', 'Latur',
       'Nanded', 'West Garo Hills', 'Dimapur', 'Bhadrak', 'Balotra',
       'Barmer', 'Dausa', 'Dungarpur', 'Nagaur', 'Neem Ka Thana',
       'Bareilly', 'Hathras', 'Lalitpur', 'Uttar Dinajpur', 'Nellore',
       'Darbhanga', 'Jamui', 'Samastipur', 'Janjgir', 'Kanker', 'Korba',
       'Koria', 'Narmada', 'Sirsa', 'Karwar(Uttar Kannad)',
       'Madikeri(Kodagu)', 'Rewa', 'Shivpuri', 'Sidhi', 'Parbhani',
       ' Jhunjhunu', 'Dudu', 'Jhalawar', 'Sanchore', 'Adilabad',
       'West Godavari', 'Kaithar', 'Kishanganj', 'Balodabazar', 'Bastar',
       'Jashpur', 'Kabirdham', 'Raigarh', 'Tumkur', 'Jhabua', 'Jalgaon',
       'Kalimpong', 'Krishna', 'Mungeli', 'Sukma', 'Surajpur', 'Bellary']

# %%
# Function to fetch weather data
def fetch_weather(city, api_key):
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching data for {city}: {response.status_code}")
        return None
    
def get_current_season():
    month = datetime.now().month
    if month in [12, 1, 2, 3]:  # Winter: December to early April
        return 'Winter'
    elif month in [4, 5, 6]:    # Summer or pre-monsoon: April to June (or July in NW India)
        return 'Summer'
    elif month in [7, 8, 9]:    # Monsoon or rainy: June to September
        return 'Monsoon'
    else:                       # Post-monsoon: October to December
        return 'Post-monsoon'

# Fetch weather data for each city and print results
count = 0
no_weather_cities = []
weather_cities = []
for city in cities:
    weather_data = fetch_weather(city, api_key)
    if weather_data:
        print(f"Weather in {city}: {weather_data['main']['temp']}°C, {weather_data['weather'][0]['description']}")
        weather_cities.append(city)
    else: 
        no_weather_cities.append(city)
        
print(len(cities))
print(len(weather_cities))
print(len(no_weather_cities))
# Out:
# Error fetching data for North and Middle Andaman : 404
# Error fetching data for Chittor: 404
# Weather in Guntur: 24.58°C, light rain
# Weather in Visakhapatnam: 28.94°C, mist
# Weather in Barpeta: 22.69°C, clear sky
# Weather in Cachar: 19.27°C, scattered clouds
# Weather in Goalpara: 22.82°C, clear sky
# Weather in Jorhat: 20.97°C, clear sky
# Error fetching data for Kamrup: 404
# Error fetching data for Karbi Anglong: 404
# Weather in Kokrajhar: 22.52°C, clear sky
# Weather in MORIGAON: 22.21°C, clear sky
# Error fetching data for Sonitpur: 404
# Weather in Araria: 23.33°C, clear sky
# Weather in Bhojpur: 13.94°C, scattered clouds
# Weather in Madhubani: 23.16°C, few clouds
# Weather in Rohtas: 24.12°C, broken clouds
# Weather in Chandigarh: 22.06°C, clear sky
# Weather in Bilaspur: 24.51°C, broken clouds
# Weather in Dhamtari: 23.22°C, scattered clouds
# Weather in Durg: 24.74°C, broken clouds
# Weather in Kondagaon: 21.37°C, scattered clouds
# Weather in Raipur: 24.4°C, broken clouds
# Weather in Rajnandgaon: 24.42°C, broken clouds
# Error fetching data for North Goa: 404
# Error fetching data for South Goa: 404
# Weather in Ahmedabad: 28.02°C, haze
# Weather in Amreli: 27.36°C, light rain
# Weather in Anand: 27.27°C, broken clouds
# Error fetching data for Banaskanth: 404
# Weather in Bharuch: 26.91°C, light rain
# Weather in Bhavnagar: 28.75°C, light rain
# Weather in Chhota Udaipur: 26.48°C, overcast clouds
# Weather in Dahod: 25.98°C, overcast clouds
# Weather in Dang: 21.17°C, moderate rain
# Error fetching data for Devbhumi Dwarka: 404
# Weather in Gandhinagar: 27.99°C, haze
# Error fetching data for Gir Somnath: 404
# Weather in Jamnagar: 28.89°C, light rain
# Weather in Junagarh: 24.02°C, scattered clouds
# Error fetching data for Kachchh: 404
# Weather in Kheda: 28.16°C, broken clouds
# Error fetching data for Mehsana: 404
# Weather in Morbi: 29.27°C, light rain
# Weather in Navsari: 25.94°C, broken clouds
# Error fetching data for Panchmahals: 404
# Weather in Patan: 19.21°C, scattered clouds
# Weather in Porbandar: 27.6°C, overcast clouds
# Weather in Rajkot: 28.61°C, light rain
# Error fetching data for Sabarkantha: 404
# Weather in Surat: 25.99°C, haze
# Weather in Surendranagar: 29.13°C, light rain
# Error fetching data for Vadodara(Baroda): 404
# Weather in Valsad: 27.38°C, light rain
# Weather in Ambala: 22.35°C, clear sky
# Weather in Bhiwani: 27.01°C, scattered clouds
# Weather in Fatehabad: 26.17°C, few clouds
# Weather in Gurgaon: 26.02°C, haze
# Weather in Hissar: 26.74°C, scattered clouds
# Error fetching data for Jhajar: 404
# Weather in Jind: 25.29°C, few clouds
# Weather in Kaithal: 23.79°C, clear sky
# Weather in Kurukshetra: 22.96°C, clear sky
# Error fetching data for Mahendragarh-Narnaul: 404
# Error fetching data for Mewat: 404
# Weather in Panchkula: 22.06°C, clear sky
# Weather in Panipat: 24.29°C, scattered clouds
# Weather in Rewari: 27.78°C, overcast clouds
# Weather in Rohtak: 27.03°C, scattered clouds
# Weather in Sonipat: 26°C, scattered clouds
# Error fetching data for Yamuna Nagar: 404
# Weather in Chamba: 18.06°C, clear sky
# Weather in Hamirpur: 28.76°C, overcast clouds
# Weather in Kangra: 19.48°C, clear sky
# Weather in Kullu: 16.61°C, clear sky
# Weather in Mandi: 15.62°C, clear sky
# Weather in Shimla: 11.23°C, clear sky
# Weather in Una: 27.68°C, scattered clouds
# Weather in Anantnag: 13.26°C, clear sky
# Error fetching data for Badgam: 404
# Weather in Baramulla: 13.63°C, clear sky
# Weather in Jammu: 23.65°C, clear sky
# Weather in Kathua: 21.4°C, clear sky
# Weather in Pulwama: 13.28°C, clear sky
# Weather in Rajouri: 18.22°C, clear sky
# Weather in Srinagar: 14.2°C, clear sky
# Weather in Udhampur: 18.54°C, clear sky
# Weather in Bangalore: 23.15°C, light rain
# Weather in Chamrajnagar: 21.69°C, overcast clouds
# Weather in Chikmagalur: 19.77°C, overcast clouds
# Weather in Chitradurga: 23.33°C, light rain
# Weather in Davangere: 22.23°C, light rain
# Weather in Kolar: 20.71°C, overcast clouds
# Weather in Koppal: 23.79°C, moderate rain
# Weather in Mandya: 21.87°C, overcast clouds
# Error fetching data for Mangalore(Dakshin Kannad): 404
# Weather in Mysore: 21.02°C, overcast clouds
# Weather in Raichur: 24.11°C, light rain
# Weather in Shimoga: 21.51°C, broken clouds
# Weather in Udupi: 25.58°C, overcast clouds
# Weather in Alappuzha: 27.11°C, overcast clouds
# Weather in Ernakulam: 24.99°C, overcast clouds
# Weather in Idukki: 21.29°C, light rain
# Weather in Kannur: 25.12°C, overcast clouds
# Error fetching data for Kasargod: 404
# Weather in Kollam: 26.25°C, light rain
# Weather in Kottayam: 24.84°C, overcast clouds
# Error fetching data for Kozhikode(Calicut): 404
# Weather in Malappuram: 24.09°C, mist
# Error fetching data for Palakad: 404
# Weather in Pathanamthitta: 24.33°C, light rain
# Error fetching data for Thirssur: 404
# Weather in Thiruvananthapuram: 27.99°C, mist
# Error fetching data for Wayanad: 404
# Weather in Alirajpur: 25.3°C, light rain
# Error fetching data for Anupur: 404
# Weather in Ashoknagar: 24.36°C, broken clouds
# Error fetching data for Badwani: 404
# Weather in Balaghat: 23.51°C, scattered clouds
# Weather in Bhind: 26.95°C, overcast clouds
# Weather in Bhopal: 24.39°C, overcast clouds
# Weather in Chhatarpur: 24.76°C, broken clouds
# Weather in Chhindwara: 22.34°C, overcast clouds
# Weather in Datia: 27.16°C, broken clouds
# Weather in Dewas: 23.1°C, light rain
# Weather in Dhar: 23.75°C, moderate rain
# Weather in Dindori: 21.61°C, broken clouds
# Weather in Guna: 23.9°C, broken clouds
# Weather in Gwalior: 26.29°C, broken clouds
# Weather in Harda: 24.67°C, broken clouds
# Weather in Hoshangabad: 24.37°C, overcast clouds
# Weather in Indore: 23.1°C, haze
# Weather in Khandwa: 24.95°C, light rain
# Weather in Khargone: 26.15°C, light rain
# Weather in Mandla: 22.58°C, broken clouds
# Weather in Mandsaur: 23.55°C, broken clouds
# Weather in Morena: 26.77°C, broken clouds
# Weather in Narsinghpur: 24.41°C, broken clouds
# Error fetching data for Neemuch: 404
# Weather in Rajgarh: 27.87°C, broken clouds
# Weather in Ratlam: 24.13°C, broken clouds
# Weather in Sagar: 24.01°C, overcast clouds
# Weather in Satna: 25.18°C, broken clouds
# Weather in Sehore: 24.58°C, overcast clouds
# Weather in Seoni: 22.98°C, broken clouds
# Weather in Shajapur: 24.3°C, overcast clouds
# Weather in Sheopur: 24.4°C, light rain
# Weather in Tikamgarh: 25.12°C, broken clouds
# Weather in Ujjain: 23.66°C, overcast clouds
# Weather in Vidisha: 24.96°C, overcast clouds
# Weather in Ahmednagar: 26.54°C, light rain
# Weather in Akola: 24.75°C, light rain
# Weather in Buldhana: 22.98°C, moderate rain
# Weather in Kolhapur: 23.47°C, scattered clouds
# Weather in Mumbai: 25.99°C, thunderstorm with light rain
# Weather in Nagpur: 26.01°C, haze
# Weather in Nashik: 24.44°C, moderate rain
# Weather in Pune: 23.97°C, light rain
# Error fetching data for Raigad: 404
# Weather in Ratnagiri: 26.39°C, light rain
# Weather in Sangli: 24.91°C, broken clouds
# Weather in Satara: 23.23°C, light rain
# Weather in Sholapur: 27.1°C, broken clouds
# Weather in Thane: 25.95°C, thunderstorm with light rain
# Weather in Yavatmal: 23.95°C, moderate rain
# Error fetching data for East Khasi Hills: 404
# Weather in Kohima: 15.32°C, scattered clouds
# Weather in Mokokchung: 14.59°C, scattered clouds
# Weather in Delhi: 26.05°C, haze
# Weather in Balasore: 25.83°C, clear sky
# Weather in Bargarh: 25.23°C, scattered clouds
# Error fetching data for Boudh: 404
# Weather in Dhenkanal: 24.86°C, scattered clouds
# Error fetching data for Kalahandi: 404
# Weather in Kendrapara: 25.47°C, few clouds
# Error fetching data for Keonjhar: 404
# Weather in Nayagarh: 23.92°C, scattered clouds
# Weather in Nuapada: 23.57°C, few clouds
# Weather in Rayagada: 23.39°C, scattered clouds
# Error fetching data for Sundergarh: 404
# Weather in Amritsar: 22.97°C, haze
# Weather in Bhatinda: 23.18°C, clear sky
# Weather in Faridkot: 23.52°C, clear sky
# Weather in Fatehgarh: 26.36°C, overcast clouds
# Weather in Fazilka: 24.36°C, clear sky
# Error fetching data for Ferozpur: 404
# Error fetching data for Gurdaspur: 404
# Weather in Hoshiarpur: 22.36°C, clear sky
# Weather in Jalandhar: 23.22°C, clear sky
# Weather in Ludhiana: 22.53°C, clear sky
# Weather in Mansa: 23.56°C, clear sky
# Weather in Moga: 23.42°C, clear sky
# Weather in Mohali: 22.15°C, clear sky
# Weather in Nawanshahr: 22.75°C, clear sky
# Weather in Pathankot: 21.08°C, clear sky
# Weather in Patiala: 22.93°C, clear sky
# Error fetching data for Ropar (Rupnagar): 404
# Weather in Sangrur: 23.88°C, clear sky
# Error fetching data for Tarntaran: 404
# Weather in Ajmer: 24.34°C, overcast clouds
# Weather in Baran: 24.29°C, scattered clouds
# Weather in Bikaner: 27.09°C, broken clouds
# Weather in Bundi: 24.01°C, broken clouds
# Weather in Churu: 26.65°C, broken clouds
# Weather in Ganganagar: 25.31°C, clear sky
# Weather in Hanumangarh: 27.15°C, clear sky
# Weather in Jalore: 27.4°C, broken clouds
# Weather in Jodhpur: 27.13°C, overcast clouds
# Error fetching data for Jodhpur Rural: 404
# Weather in Pratapgarh: 23.17°C, broken clouds
# Weather in Sikar: 25.38°C, overcast clouds
# Weather in Tonk: 24.77°C, overcast clouds
# Weather in Udaipur: 22.99°C, broken clouds
# Weather in Ariyalur: 26.08°C, light rain
# Weather in Chengalpattu: 28.52°C, moderate rain
# Weather in Coimbatore: 22.88°C, mist
# Weather in Cuddalore: 27.39°C, moderate rain
# Weather in Dharmapuri: 23.09°C, overcast clouds
# Weather in Dindigul: 23.4°C, heavy intensity rain
# Weather in Erode: 25.2°C, light rain
# Error fetching data for Kallakuruchi: 404
# Error fetching data for Kancheepuram: 404
# Weather in Karur: 24.39°C, light rain
# Weather in Krishnagiri: 22.62°C, broken clouds
# Weather in Madurai: 26.01°C, mist
# Weather in Nagapattinam: 26.89°C, light rain
# Error fetching data for Nagercoil (Kannyiakumari): 404
# Weather in Namakkal: 24.73°C, light rain
# Weather in Perambalur: 25.75°C, light rain
# Weather in Pudukkottai: 26.92°C, light rain
# Weather in Ramanathapuram: 27.17°C, moderate rain
# Error fetching data for Ranipet: 404
# Weather in Salem: 24.19°C, light rain
# Weather in Sivaganga: 26.23°C, light rain
# Weather in Tenkasi: 24.61°C, moderate rain
# Weather in Thanjavur: 26.13°C, light rain
# Error fetching data for The Nilgiris: 404
# Weather in Theni: 24.87°C, moderate rain
# Error fetching data for Thiruchirappalli: 404
# Error fetching data for Thirunelveli: 404
# Error fetching data for Thirupathur: 404
# Error fetching data for Thirupur: 404
# Error fetching data for Thiruvannamalai: 404
# Weather in Thiruvarur: 26.22°C, light rain
# Error fetching data for Thiruvellore: 404
# Error fetching data for Tuticorin: 404
# Weather in Vellore: 24.22°C, overcast clouds
# Weather in Villupuram: 25.83°C, light rain
# Weather in Virudhunagar: 26.23°C, moderate rain
# Weather in Hyderabad: 26.23°C, scattered clouds
# Weather in Karimnagar: 24.32°C, scattered clouds
# Weather in Khammam: 24.32°C, broken clouds
# Weather in Mahbubnagar: 22.91°C, broken clouds
# Weather in Medak: 22.91°C, light rain
# Weather in Nalgonda: 24.32°C, scattered clouds
# Weather in Nizamabad: 23.34°C, light rain
# Error fetching data for Ranga Reddy: 404
# Weather in Warangal: 24.08°C, scattered clouds
# Weather in Gomati: 16.35°C, scattered clouds
# Error fetching data for North Tripura: 404
# Error fetching data for Sepahijala: 404
# Error fetching data for Unokoti: 404
# Weather in Agra: 27.86°C, overcast clouds
# Weather in Aligarh: 26.59°C, overcast clouds
# Error fetching data for Ambedkarnagar: 404
# Weather in Amethi: 26.17°C, broken clouds
# Weather in Amroha: 24.04°C, broken clouds
# Weather in Auraiya: 27.16°C, overcast clouds
# Weather in Ayodhya: 24.22°C, broken clouds
# Weather in Azamgarh: 24.95°C, scattered clouds
# Weather in Badaun: 24.89°C, broken clouds
# Weather in Baghpat: 26.04°C, scattered clouds
# Weather in Bahraich: 22.68°C, overcast clouds
# Weather in Ballia: 24.14°C, scattered clouds
# Weather in Balrampur: 22.29°C, overcast clouds
# Weather in Banda: 27.86°C, overcast clouds
# Weather in Barabanki: 25.01°C, overcast clouds
# Weather in Basti: 23.92°C, broken clouds
# Error fetching data for Bhadohi(Sant Ravi Nagar): 404
# Weather in Bijnor: 22.94°C, broken clouds
# Error fetching data for Bulandshahar: 404
# Weather in Chandauli: 24.03°C, overcast clouds
# Weather in Etah: 26.37°C, overcast clouds
# Weather in Etawah: 26.44°C, overcast clouds
# Error fetching data for Farukhabad: 404
# Weather in Fatehpur: 26.98°C, overcast clouds
# Weather in Firozabad: 26.94°C, overcast clouds
# Weather in Gautam Budh Nagar: 26.16°C, broken clouds
# Weather in Ghaziabad: 26.08°C, broken clouds
# Weather in Ghazipur: 24.4°C, broken clouds
# Weather in Gonda: 23.8°C, overcast clouds
# Weather in Gorakhpur: 25.74°C, scattered clouds
# Weather in Hardoi: 25.27°C, overcast clouds
# Error fetching data for Jalaun (Orai): 404
# Weather in Jaunpur: 24.01°C, broken clouds
# Weather in Jhansi: 27.18°C, broken clouds
# Error fetching data for Kannuj: 404
# Weather in Kanpur: 27.09°C, overcast clouds
# Weather in Kasganj: 25.99°C, overcast clouds
# Weather in Kaushambi: 26.13°C, broken clouds
# Error fetching data for Khiri (Lakhimpur): 404
# Weather in Lakhimpur: 22.7°C, broken clouds
# Weather in Lucknow: 24.99°C, mist
# Weather in Maharajganj: 22.53°C, broken clouds
# Weather in Mahoba: 27.06°C, overcast clouds
# Weather in Mainpuri: 26.6°C, overcast clouds
# Weather in Mathura: 27.21°C, overcast clouds
# Error fetching data for Mau(Maunathbhanjan): 404
# Weather in Meerut: 26.7°C, scattered clouds
# Weather in Mirzapur: 23.98°C, broken clouds
# Weather in Muzaffarnagar: 22.67°C, scattered clouds
# Error fetching data for Pillibhit: 404
# Error fetching data for Prayagraj: 404
# Error fetching data for Raebarelli: 404
# Weather in Rampur: 22.49°C, scattered clouds
# Weather in Saharanpur: 21.68°C, clear sky
# Weather in Sambhal: 24.1°C, broken clouds
# Error fetching data for Sant Kabir Nagar: 404
# Weather in Shahjahanpur: 23.62°C, broken clouds
# Weather in Shamli: 23.21°C, scattered clouds
# Error fetching data for Siddharth Nagar: 404
# Weather in Sitapur: 24.25°C, overcast clouds
# Weather in Unnao: 24.99°C, overcast clouds
# Weather in Varanasi: 24.05°C, mist
# Weather in Champawat: 13.37°C, clear sky
# Error fetching data for Dehradoon: 404
# Weather in Haridwar: 20°C, few clouds
# Error fetching data for Nanital: 404
# Error fetching data for UdhamSinghNagar: 404
# Error fetching data for Alipurduar: 404
# Weather in Bankura: 25.41°C, few clouds
# Error fetching data for Birbhum: 404
# Weather in Darjeeling: 9.67°C, scattered clouds
# Weather in Howrah: 29°C, haze
# Weather in Jalpaiguri: 22.61°C, clear sky
# Weather in Kolkata: 28.97°C, haze
# Error fetching data for Medinipur(E): 404
# Error fetching data for Medinipur(W): 404
# Weather in Murshidabad: 25.23°C, clear sky
# Error fetching data for Nadia: 404
# Error fetching data for North 24 Parganas: 404
# Error fetching data for Paschim Bardhaman: 404
# Error fetching data for Purba Bardhaman: 404
# Weather in Puruliya: 24.5°C, scattered clouds
# Error fetching data for Sounth 24 Parganas: 404
# Error fetching data for East Godavari: 404
# Weather in Sibsagar: 20.79°C, clear sky
# Weather in Vaishali: 28.95°C, few clouds
# Error fetching data for Surguja: 404
# Weather in Dharwad: 24.12°C, broken clouds
# Error fetching data for Kalburgi: 404
# Error fetching data for Yadgiri: 404
# Weather in Damoh: 24.63°C, broken clouds
# Weather in Jabalpur: 23.78°C, broken clouds
# Weather in Katni: 23.56°C, broken clouds
# Weather in Panna: 24.18°C, overcast clouds
# Weather in Raisen: 24.28°C, overcast clouds
# Error fetching data for Shehdol: 404
# Error fetching data for Umariya: 404
# Weather in Chandrapur: 24.79°C, broken clouds
# Weather in Hingoli: 23.09°C, light rain
# Weather in Latur: 24.99°C, overcast clouds
# Error fetching data for Nanded: 404
# Error fetching data for West Garo Hills: 404
# Weather in Dimapur: 21.54°C, scattered clouds
# Weather in Bhadrak: 25.57°C, clear sky
# Weather in Balotra: 28.26°C, overcast clouds
# Weather in Barmer: 27.25°C, overcast clouds
# Weather in Dausa: 26.08°C, overcast clouds
# Weather in Dungarpur: 25.07°C, scattered clouds
# Weather in Nagaur: 27.07°C, overcast clouds
# Weather in Neem Ka Thana: 25.13°C, overcast clouds
# Weather in Bareilly: 23.22°C, broken clouds
# Weather in Hathras: 26.73°C, overcast clouds
# Weather in Lalitpur: 19.21°C, scattered clouds
# Error fetching data for Uttar Dinajpur: 404
# Weather in Nellore: 27.03°C, light rain
# Weather in Darbhanga: 23.66°C, few clouds
# Weather in Jamui: 23.96°C, scattered clouds
# Weather in Samastipur: 24.09°C, few clouds
# Weather in Janjgir: 25.48°C, broken clouds
# Weather in Kanker: 22.39°C, broken clouds
# Weather in Korba: 24.78°C, overcast clouds
# Weather in Koria: 35.91°C, broken clouds
# Weather in Narmada: 25.75°C, broken clouds
# Weather in Sirsa: 27.02°C, few clouds
# Error fetching data for Karwar(Uttar Kannad): 404
# Error fetching data for Madikeri(Kodagu): 404
# Weather in Rewa: 25.25°C, broken clouds
# Weather in Shivpuri: 23.89°C, broken clouds
# Weather in Sidhi: 24.14°C, broken clouds
# Weather in Parbhani: 24.3°C, light rain
# Error fetching data for  Jhunjhunu: 404
# Weather in Dudu: 25.54°C, overcast clouds
# Weather in Jhalawar: 23.96°C, few clouds
# Weather in Sanchore: 28.45°C, broken clouds
# Weather in Adilabad: 24.55°C, overcast clouds
# Error fetching data for West Godavari: 404
# Error fetching data for Kaithar: 404
# Weather in Kishanganj: 23.18°C, clear sky
# Error fetching data for Balodabazar: 404
# Error fetching data for Bastar: 404
# Error fetching data for Jashpur: 404
# Error fetching data for Kabirdham: 404
# Weather in Raigarh: 25.34°C, scattered clouds
# Weather in Tumkur: 21.06°C, light rain
# Weather in Jhabua: 25.73°C, overcast clouds
# Weather in Jalgaon: 26.04°C, light rain
# Weather in Kalimpong: 16.33°C, few clouds
# Error fetching data for Krishna: 404
# Weather in Mungeli: 24.34°C, broken clouds
# Weather in Sukma: 24°C, broken clouds
# Weather in Surajpur: 21.63°C, few clouds
# Weather in Bellary: 24.07°C, light rain

# %%
def job():
    global weather_df
    for city in cities:
        weather_data = fetch_weather(city, api_key)
        if weather_data is not None:
            new_data = pd.DataFrame([{
                "timestamp": datetime.now(),
                "city": city,
                "temperature": weather_data['main']['temp'],
                "humidity": weather_data['main']['humidity'],
                "pressure": weather_data['main']['pressure'],
                "weather": weather_data['weather'][0]['description'],
                "wind_speed": weather_data['wind']['speed'],
                "season": get_current_season()
            }])
            weather_df = pd.concat([weather_df, new_data], ignore_index=True)

    # Save the DataFrame to CSV
    weather_df.to_csv('weather_data.csv', index=False)
    print("Updated weather DataFrame:")
    print(weather_df)

# For testing purposes, run the job function
job()
print("Final DataFrame:")
print(weather_df)
# Out:
# 414
# 314
# 100
# Error fetching data for North and Middle Andaman : 404
# Error fetching data for Chittor: 404
# Error fetching data for Kamrup: 404
# Error fetching data for Karbi Anglong: 404
# Error fetching data for Sonitpur: 404
# Error fetching data for North Goa: 404
# Error fetching data for South Goa: 404
# Error fetching data for Banaskanth: 404
# Error fetching data for Devbhumi Dwarka: 404
# Error fetching data for Gir Somnath: 404
# Error fetching data for Kachchh: 404
# Error fetching data for Mehsana: 404
# Error fetching data for Panchmahals: 404
# Error fetching data for Sabarkantha: 404
# Error fetching data for Vadodara(Baroda): 404
# Error fetching data for Jhajar: 404
# Error fetching data for Mahendragarh-Narnaul: 404
# Error fetching data for Mewat: 404
# Error fetching data for Yamuna Nagar: 404
# Error fetching data for Badgam: 404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 38
#      35     print(weather_df)
#      37 # For testing purposes, run the job function
# ---> 38 job()
#      39 print("Final DataFrame:")
#      40 print(weather_df)
#
# Cell In[7], line 18, in job()
#      16 global weather_df
#      17 for city in cities:
# ---> 18     weather_data = fetch_weather(city, api_key)
#      19     if weather_data is not None:
#      20         new_data = pd.DataFrame([{
#      21             "timestamp": datetime.now(),
#      22             "city": city,
#    (...)
#      28             "season": get_current_season()
#      29         }])
#
# Cell In[6], line 4, in fetch_weather(city, api_key)
#       2 def fetch_weather(city, api_key):
#       3     url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
# ----> 4     response = requests.get(url)
#       5     if response.status_code == 200:
#       6         return response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:495, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#     494 try:
# --> 495     conn.request(
#     496         method,
#     497         url,
#     498         body=body,
#     499         headers=headers,
#     500         chunked=chunked,
#     501         preload_content=preload_content,
#     502         decode_content=decode_content,
#     503         enforce_content_length=enforce_content_length,
#     504     )
#     506 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     507 # legitimately able to close the connection after sending a valid response.
#     508 # With this behaviour, the received response is still readable.
#     509 except BrokenPipeError:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:441, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     439 for header, value in headers.items():
#     440     self.putheader(header, value)
# --> 441 self.endheaders()
#     443 # If we're given a body we start sending that in chunks.
#     444 if chunks is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:279, in HTTPConnection.connect(self)
#     278 def connect(self) -> None:
# --> 279     self.sock = self._new_conn()
#     280     if self._tunnel_host:
#     281         # If we're tunneling it means we're connected to our proxy.
#     282         self._has_connected_to_proxy = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %%
no_weather_cities
# Out:
# ['North and Middle Andaman ',
#  'Chittor',
#  'Kamrup',
#  'Karbi Anglong',
#  'Sonitpur',
#  'North Goa',
#  'South Goa',
#  'Banaskanth',
#  'Devbhumi Dwarka',
#  'Gir Somnath',
#  'Kachchh',
#  'Mehsana',
#  'Panchmahals',
#  'Sabarkantha',
#  'Vadodara(Baroda)',
#  'Jhajar',
#  'Mahendragarh-Narnaul',
#  'Mewat',
#  'Yamuna Nagar',
#  'Badgam',
#  'Mangalore(Dakshin Kannad)',
#  'Kasargod',
#  'Kozhikode(Calicut)',
#  'Palakad',
#  'Thirssur',
#  'Wayanad',
#  'Anupur',
#  'Badwani',
#  'Neemuch',
#  'Raigad',
#  'East Khasi Hills',
#  'Boudh',
#  'Kalahandi',
#  'Keonjhar',
#  'Nuapada',
#  'Sundergarh',
#  'Ferozpur',
#  'Gurdaspur',
#  'Ropar (Rupnagar)',
#  'Tarntaran',
#  'Jodhpur Rural',
#  'Kallakuruchi',
#  'Kancheepuram',
#  'Nagercoil (Kannyiakumari)',
#  'Ranipet',
#  'The Nilgiris',
#  'Thiruchirappalli',
#  'Thirunelveli',
#  'Thirupathur',
#  'Thirupur',
#  'Thiruvannamalai',
#  'Thiruvellore',
#  'Tuticorin',
#  'Ranga Reddy',
#  'North Tripura',
#  'Sepahijala',
#  'Unokoti',
#  'Ambedkarnagar',
#  'Bhadohi(Sant Ravi Nagar)',
#  'Bulandshahar',
#  'Farukhabad',
#  'Jalaun (Orai)',
#  'Kannuj',
#  'Khiri (Lakhimpur)',
#  'Mau(Maunathbhanjan)',
#  'Pillibhit',
#  'Prayagraj',
#  'Raebarelli',
#  'Sant Kabir Nagar',
#  'Siddharth Nagar',
#  'Dehradoon',
#  'Nanital',
#  'UdhamSinghNagar',
#  'Alipurduar',
#  'Birbhum',
#  'Medinipur(E)',
#  'Medinipur(W)',
#  'Nadia',
#  'North 24 Parganas',
#  'Paschim Bardhaman',
#  'Purba Bardhaman',
#  'Sounth 24 Parganas',
#  'East Godavari',
#  'Surguja',
#  'Kalburgi',
#  'Yadgiri',
#  'Shehdol',
#  'Umariya',
#  'Nanded',
#  'West Garo Hills',
#  'Uttar Dinajpur',
#  'Karwar(Uttar Kannad)',
#  'Madikeri(Kodagu)',
#  ' Jhunjhunu',
#  'West Godavari',
#  'Kaithar',
#  'Balodabazar',
#  'Bastar',
#  'Jashpur',
#  'Kabirdham',
#  'Krishna',
#  'Sukma']
